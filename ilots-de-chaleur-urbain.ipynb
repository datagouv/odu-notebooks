# %% [markdown]
# #  Défi open data : Îlots de chaleur urbain

# %% [markdown]
# Les villes sont confrontées à un phénomène croissant d’« îlot de chaleur urbain » (ICU) : une différence de température entre les milieux urbains et les zones rurales environnantes (+4°C en moyenne et pouvant aller jusqu’à +12°C).
#
# Ce phénomène est lié à plusieurs facteurs (matériaux de construction des bâtiments, des voiries et autres infrastructures, occupation du sol, morphologie urbaine, déficit de végétalisation, activités humaines, etc.) et engendre des risques variés (pour la santé publique, les consommations énergétiques, l’attractivité des territoires, la biodiversité, etc.).
#
# **La problématique**
#
# Ce projet vous propose **d’identifier et de caractériser les zones pouvant être exposées à un effet d’îlot de chaleur urbain, ainsi que les zones à enjeu (habitées par des populations vulnérables)**, dans la commune de votre choix.
#
# Beaucoup de données ouvertes sont mises à disposition pour vous permettre de répondre à ce sujet. Plusieurs jeux de données ont déjà été chargés dans cet environnement ([cf. liste](https://defis.data.gouv.fr/defis/6639ea1a5fde712a09fa0c67/)) et vous pouvez bien évidemment en ajouter d’autres selon vos besoins.
#
# Une fois vos travaux terminés, partagez-les avec l’ensemble de la communauté [en publiant une réutilisation sur data.gouv.fr](https://guides.data.gouv.fr/guide-data.gouv.fr/reutilisations) !

# %% [markdown]
# # Importer des données
# Nous mettons à disposition une fonction utilitaire qui permet de charger la majorité des ressources de data.gouv.fr à partir de leur identifiant sur le site (exemple : `"2876a346-d50c-4911-934e-19ee07b0e503"`). Vous pouvez l'utiliser comme suit :

# %%
from utils import load_table_from_resource_id

df = load_table_from_resource_id(
    'b45b2b9b-889c-4361-8b72-11d5995b8e85',
    encoding='cp1252'
)
df
# Out:
#        CODE r_PHASE  PANEL  r_BCON1             r_BCON2 r_MMAT  \
# 0    QSEL01      AP      1   1969.0                 NaN  Béton
# 1    QSEL01      AP      1   1969.0                 NaN  Béton
# 2    QSEL01      AP      1   1969.0                 NaN  Béton
# 3    QSEL01      AV      1   1969.0                 NaN  Béton
# 4    QSEL01      AV      1   1969.0                 NaN  Béton
# ..      ...     ...    ...      ...                 ...    ...
# 360  QSEL74      AP      2      NaN  Entre 1949 et 1961  Béton
# 361  QSEL74      AP      2      NaN  Entre 1949 et 1961  Béton
# 362  QSEL74      AP      2      NaN  Entre 1949 et 1961  Béton
# 363  QSEL74      AP      2      NaN  Entre 1949 et 1961  Béton
# 364  QSEL74      AP      2      NaN  Entre 1949 et 1961  Béton
#
#                                 MTIS  \
# 0    Isolation par l’extérieur (ITE)
# 1    Isolation par l’extérieur (ITE)
# 2    Isolation par l’extérieur (ITE)
# 3                    Pas d’isolation
# 4                    Pas d’isolation
# ..                               ...
# 360      Isolation mixte (ITI + ITE)
# 361      Isolation mixte (ITI + ITE)
# 362      Isolation mixte (ITI + ITE)
# 363      Isolation mixte (ITI + ITE)
# 364      Isolation mixte (ITI + ITE)
#
#                                                   MMIS       r_PISO  \
# 0    Isolants synthétiques (polystyrène, polyurétha...  Ne sait pas
# 1    Isolants synthétiques (polystyrène, polyurétha...  Ne sait pas
# 2    Isolants synthétiques (polystyrène, polyurétha...  Ne sait pas
# 3                                                  NaN          Non
# 4                                                  NaN          Non
# ..                                                 ...          ...
# 360  Isolant naturels (bois, paille, coton, chanvre...          Oui
# 361  Isolant naturels (bois, paille, coton, chanvre...          Oui
# 362  Isolant naturels (bois, paille, coton, chanvre...          Oui
# 363  Isolant naturels (bois, paille, coton, chanvre...          Oui
# 364  Isolant naturels (bois, paille, coton, chanvre...          Oui
#
#                                                  PISO1  ... MINF1  \
# 0                                                  NaN  ...   NaN
# 1                                                  NaN  ...   NaN
# 2                                                  NaN  ...   NaN
# 3                                                  NaN  ...   NaN
# 4                                                  NaN  ...   NaN
# ..                                                 ...  ...   ...
# 360  Isolant naturels (bois, paille, coton, chanvre...  ...   NaN
# 361  Isolant naturels (bois, paille, coton, chanvre...  ...   NaN
# 362  Isolant naturels (bois, paille, coton, chanvre...  ...   NaN
# 363  Isolant naturels (bois, paille, coton, chanvre...  ...   NaN
# 364  Isolant naturels (bois, paille, coton, chanvre...  ...   NaN
#
#                         r_BTYP                               r_MTYP  \
# 0      Un immeuble collectif ?                                  NaN
# 1      Un immeuble collectif ?                                  NaN
# 2      Un immeuble collectif ?                                  NaN
# 3      Un immeuble collectif ?                                  NaN
# 4      Un immeuble collectif ?                                  NaN
# ..                         ...                                  ...
# 360  Une maison individuelle ?  Maison jumelée, en bande ou groupée
# 361  Une maison individuelle ?  Maison jumelée, en bande ou groupée
# 362  Une maison individuelle ?  Maison jumelée, en bande ou groupée
# 363  Une maison individuelle ?  Maison jumelée, en bande ou groupée
# 364  Une maison individuelle ?  Maison jumelée, en bande ou groupée
#
#                                                   LVDS  \
# 0    D’une ventilation mécanique contrôlée (VMC) (i...
# 1    D’une ventilation mécanique contrôlée (VMC) (i...
# 2    D’une ventilation mécanique contrôlée (VMC) (i...
# 3           Aucun dispositif spécifique de ventilation
# 4           Aucun dispositif spécifique de ventilation
# ..                                                 ...
# 360  D’une ventilation mécanique contrôlée (VMC) (i...
# 361  D’une ventilation mécanique contrôlée (VMC) (i...
# 362  D’une ventilation mécanique contrôlée (VMC) (i...
# 363  D’une ventilation mécanique contrôlée (VMC) (i...
# 364  D’une ventilation mécanique contrôlée (VMC) (i...
#
#                                                   LVMC      POLLUANT  \
# 0    Simple flux par extraction (système composé d’...  Acétaldéhyde
# 1    Simple flux par extraction (système composé d’...  Formaldéhyde
# 2    Simple flux par extraction (système composé d’...   Hexaldéhyde
# 3                                                  NaN  Acétaldéhyde
# 4                                                  NaN  Formaldéhyde
# ..                                                 ...           ...
# 360  Double flux(système composé d’un double réseau...       Styrène
# 361  Double flux(système composé d’un double réseau...       Toluène
# 362  Double flux(système composé d’un double réseau...           NO2
# 363  Double flux(système composé d’un double réseau...         PM2.5
# 364  Double flux(système composé d’un double réseau...         Radon
#
#                  CONC  unité                                    Statut.ICF  \
# 0    8,72834829413519  µg/m3  Présence d'une contamination fongique active
# 1    30,7495430410241  µg/m3  Présence d'une contamination fongique active
# 2    18,3559675505225  µg/m3  Présence d'une contamination fongique active
# 3     55,208891960339  µg/m3  Présence d'une contamination fongique active
# 4    53,4031791400043  µg/m3  Présence d'une contamination fongique active
# ..                ...    ...                                           ...
# 360             0,045  µg/m3                                           NaN
# 361             0,851  µg/m3                                           NaN
# 362  13,9332616120535  µg/m3                                           NaN
# 363  9,14592836818572  µg/m3                                           NaN
# 364  76,3849065259777  Bq/m3                                           NaN
#
#                                             Nom_piece
# 0    Chambre principale du référent / pièce de studio
# 1    Chambre principale du référent / pièce de studio
# 2    Chambre principale du référent / pièce de studio
# 3    Chambre principale du référent / pièce de studio
# 4    Chambre principale du référent / pièce de studio
# ..                                                ...
# 360  Chambre principale du référent / pièce de studio
# 361  Chambre principale du référent / pièce de studio
# 362  Chambre principale du référent / pièce de studio
# 363                       Séjour/Salon/Salle à manger
# 364                       Séjour/Salon/Salle à manger
#
# [365 rows x 60 columns]

# %% [markdown]
# # Exemple de réalisation : ICU du futur, créé pendant le [Hackathon Météo France](https://www.data.gouv.fr/fr/posts/retour-sur-le-hackathon-donnees-ouvertes-meteo-france/)

# %% [markdown]
# #### https://www.data.gouv.fr/fr/reuses/des-icu-du-futur-1/
