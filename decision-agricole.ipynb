# %% [markdown]
# # Défi open data : Décision agricole

# %% [markdown]
# **Les productions agricoles sont fortement déterminées par les conditions météorologiques**, tout au long du cycle cultural :
# * la croissance des plantes est principalement pilotée par l’accumulation des températures ;
# * les besoins en irrigation dépendent des réserves en eau dans le sol (constituées lors des précipitations antérieures) ;
# * le développement d’une maladie peut résulter de l’accumulation de certaines conditions météorologiques ;
# * etc.
#
# **La problématique**
#
# Ce projet vous propose **d’exploiter les données publiques météorologiques pour informer la prise de décision dans le domaine agricole**.
#
# Beaucoup de données ouvertes sont mises à disposition pour vous permettre de répondre à ce sujet. Plusieurs jeux de données ont déjà été chargés dans cet environnement ([cf. liste](https://defis.data.gouv.fr/defis/6639e67fa95c6e4f1da70e39/)) et vous pouvez bien évidemment en ajouter d’autres selon vos besoins.
#
# Une fois vos travaux terminés, partagez-les avec l’ensemble de la communauté [en publiant une réutilisation sur data.gouv.fr](https://guides.data.gouv.fr/guide-data.gouv.fr/reutilisations) !

# %% [markdown]
# # Importer des données
# Nous mettons à disposition une fonction utilitaire qui permet de charger la majorité des ressources de data.gouv.fr à partir de leur identifiant sur le site (exemple : `"2876a346-d50c-4911-934e-19ee07b0e503"`). Vous pouvez l'utiliser comme suit :

# %%
from utils import load_table_from_resource_id

df = load_table_from_resource_id('cb51408e-2b97-43a4-94e2-c0de5c3bf5b2')
df
# Out:
# Info : ce fichier zippé contient plusieurs fichiers, ouverture du plus large : produits_usages_utf8.csv
# C:\Users\Dinum\Documents\Projets\tests\odu-notebooks\utils.py:44: DtypeWarning: Columns (0,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(
#               numero AMM               nom produit  \
# 0                8800006             DIMATE BF 400
# 1                8800006             DIMATE BF 400
# 2                8800006             DIMATE BF 400
# 3                8800006             DIMATE BF 400
# 4                8800006             DIMATE BF 400
# ...                  ...                       ...
# 81735    2190686/2161101  REVYSTAR XL + PRIAXOR EC
# 81736    2100037/2010280   FILAN SC + CARAMBA STAR
# 81737    2100037/2010280   FILAN SC + CARAMBA STAR
# 81738  2060088 - 2100111            CAMIX + ELUMIS
# 81739    2140173/2110096            LIBRAX + BRAVO
#
#                                        identifiant usage  date decision  \
# 0                       Artichaut*Trt Part.Aer.*Pucerons     26/09/2012
# 1                          Carotte*Trt Part.Aer.*Mouches            NaN
# 2      Chicorées - Production de racines*Trt Sol*Mouches            NaN
# 3                           Choux*Trt Part.Aer.*Pucerons            NaN
# 4                          Laitue*Trt Part.Aer.*Pucerons            NaN
# ...                                                  ...            ...
# 81735                 Orge*Trt Part.Aer.*Rhynchosporiose     28/04/2021
# 81736    Crucifères oléagineuses*Trt Part.Aer.*Oïdium(s)     09/10/2015
# 81737  Crucifères oléagineuses*Trt Part.Aer.*Scléroti...     09/10/2015
# 81738                                    Maïs*Désherbage     25/03/2022
# 81739                    Blé*Trt Part.Aer.*Septoriose(s)     29/10/2019
#
#        stade cultural min (BBCH)  tade cultural max (BBCH) etat usage  \
# 0                            NaN                       NaN    Retrait
# 1                            NaN                       NaN    Retrait
# 2                            NaN                       NaN    Retrait
# 3                            NaN                       NaN    Retrait
# 4                            NaN                       NaN    Retrait
# ...                          ...                       ...        ...
# 81735                       30.0                      59.0   Autorisé
# 81736                        NaN                       NaN    Retrait
# 81737                        NaN                       NaN    Retrait
# 81738                       12.0                      14.0   Autorisé
# 81739                        NaN                       NaN    Retrait
#
#        dose retenue dose retenue unite  delai avant recolte jour  ...  \
# 0              0.60               L/ha                       NaN  ...
# 1              0.50               L/ha                       NaN  ...
# 2              0.75               L/ha                       NaN  ...
# 3              0.60               L/ha                       NaN  ...
# 4              0.60               L/ha                       NaN  ...
# ...             ...                ...                       ...  ...
# 81735          1.50               L/ha                      35.0  ...
# 81736           NaN                NaN                      56.0  ...
# 81737           NaN                NaN                      56.0  ...
# 81738          3.10               L/ha                       NaN  ...
# 81739          2.00               L/ha                      56.0  ...
#
#        nombre max d'application  date fin distribution date fin utilisation  \
# 0                           3.0             31/03/2013           31/03/2014
# 1                           3.0                    NaN                  NaN
# 2                           NaN                    NaN                  NaN
# 3                           2.0                    NaN                  NaN
# 4                           1.0                    NaN                  NaN
# ...                         ...                    ...                  ...
# 81735                       1.0                    NaN                  NaN
# 81736                       1.0                    NaN                  NaN
# 81737                       1.0                    NaN                  NaN
# 81738                       1.0                    NaN                  NaN
# 81739                       1.0             20/02/2020           20/05/2020
#
#                                         condition emploi ZNT aquatique (en m)  \
# 0                                                    NaN                  NaN
# 1                                                    NaN                  NaN
# 2                                                    NaN                  NaN
# 3                                                    NaN                  NaN
# 4                                                    NaN                  NaN
# ...                                                  ...                  ...
# 81735  REVYSTAR XL 0,75 L/ha + PRIAXOR EC 0,75 L/ha. ...                 20.0
# 81736                                                NaN                  NaN
# 81737                                                NaN                  NaN
# 81738                               Uniquement sur mais.                 20.0
# 81739                                                NaN                  NaN
#
#        ZNT arthropodes non cibles (en m)  ZNT plantes non cibles (en m)  \
# 0                                    NaN                            NaN
# 1                                    NaN                            NaN
# 2                                    NaN                            NaN
# 3                                    NaN                            NaN
# 4                                    NaN                            NaN
# ...                                  ...                            ...
# 81735                                NaN                            NaN
# 81736                                NaN                            NaN
# 81737                                NaN                            NaN
# 81738                                NaN                            5.0
# 81739                                NaN                            NaN
#
#        mentions autorisees  intervalle minimum entre applications (jour)  \
# 0                      NaN                                           NaN
# 1                      NaN                                           NaN
# 2                      NaN                                           NaN
# 3                      NaN                                           NaN
# 4                      NaN                                           NaN
# ...                    ...                                           ...
# 81735                  NaN                                           NaN
# 81736                  NaN                                           NaN
# 81737                  NaN                                           NaN
# 81738                  NaN                                           NaN
# 81739                  NaN                                           NaN
#
#        Unnamed: 20
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 81735          NaN
# 81736          NaN
# 81737          NaN
# 81738          NaN
# 81739          NaN
#
# [81740 rows x 21 columns]

# %% [markdown]
# # Exemple de réalisation : évolution des surfaces d'agriculture bio par culture

# %%
from io import BytesIO
import requests
import zipfile
import gzip
import geopandas as gpd
import pandas as pd
import plotly.express as px

# %%
# on récupère les fichiers nationaux les plus récents et anciens (geojson.gz et gpkg.zip)
content = requests.get('https://www.data.gouv.fr/fr/datasets/r/a0d9e304-97d0-4871-ad32-70a5c47aa71d').content
with gzip.open(BytesIO(content), 'r') as f:
    df_2019 = gpd.read_file(f)
df_2019['SURFACE_HA'] = df_2019['SURFACE_HA'].astype(float)
df_2019
# Out:
#         MILLESIME  BIO CODE_CULTU  \
# 0          2019.0  1.0        VRG
# 1          2019.0  1.0        VRG
# 2          2019.0  1.0        VRG
# 3          2019.0  1.0        VRG
# 4          2019.0  1.0        SPH
# ...           ...  ...        ...
# 823816     2019.0  1.0        OLI
# 823817     2019.0  1.0        SNE
# 823818     2019.0  1.0        SNE
# 823819     2019.0  1.0        SNE
# 823820     2019.0  1.0        VRC
#
#                                                 LBL_CULTU          GRP_CULTU  \
# 0                                                  Verger            Vergers
# 1                                                  Verger            Vergers
# 2                                                  Verger            Vergers
# 3                                                  Verger            Vergers
# 4       Surface pastorale - herbe prédominante et ress...  Estives et landes
# ...                                                   ...                ...
# 823816                                          Oliveraie           Oliviers
# 823817      Surface agricole temporairement non exploitée             Divers
# 823818      Surface agricole temporairement non exploitée             Divers
# 823819      Surface agricole temporairement non exploitée             Divers
# 823820                            Vigne : raisins de cuve             Vignes
#
#         SURFACE_HA                                           geometry
# 0             0.40  POLYGON ((-6263686.642 6119214.074, -6263644.4...
# 1             0.44  POLYGON ((-6263666.402 6119142.639, -6263634.5...
# 2             0.24  POLYGON ((-6263592.086 6119007.742, -6263541.1...
# 3             0.21  POLYGON ((-6263607.374 6119027.623, -6263596.0...
# 4             3.01  POLYGON ((-6263600.840 6119000.949, -6263699.2...
# ...            ...                                                ...
# 823816        0.53  POLYGON ((1220904.568 6193163.615, 1220903.510...
# 823817        0.79  POLYGON ((1216162.411 6159010.181, 1216146.272...
# 823818        1.44  POLYGON ((1236904.061 6154722.606, 1236914.561...
# 823819        3.99  POLYGON ((1235990.434 6161777.538, 1235980.116...
# 823820        0.94  POLYGON ((1220678.038 6198253.837, 1220676.774...
#
# [823821 rows x 7 columns]

# %%
content = requests.get('https://www.data.gouv.fr/fr/datasets/r/36314eff-2712-4d6a-b091-7752a5b318bb').content
z = zipfile.ZipFile(BytesIO(content))
df_2022 = gpd.read_file(z.open('rpg-bio-2022-national.gpkg'), sep=';')
df_2022
# Out:
#               gid  millesime code_culture  \
# 0         4420687       2022          PPH
# 1             333       2022          PTR
# 2             337       2022          BTH
# 3             464       2022          BTH
# 4             480       2022          BTH
# ...           ...        ...          ...
# 1085952  10006617       2022          FLA
# 1085953  10007102       2022          ACA
# 1085954  10007842       2022          FLP
# 1085955   6316882       2022          LUZ
# 1085956   6810613       2022          PPH
#
#                                                lbl_culture  \
# 0        Prairie permanente - herbe prédominante (resso...
# 1               Autre prairie temporaire de 5 ans ou moins
# 2                                       Blé tendre d’hiver
# 3                                       Blé tendre d’hiver
# 4                                       Blé tendre d’hiver
# ...                                                    ...
# 1085952                       Autre légume ou fruit annuel
# 1085953  Autre culture non précisée dans la liste (admi...
# 1085954                      Autre légume ou fruit pérenne
# 1085955                                      Autre luzerne
# 1085956  Prairie permanente - herbe prédominante (resso...
#
#                   grp_culture  surface_ha code_commune_insee  \
# 0        Prairies permanentes        0.38              38513
# 1        Prairies temporaires        2.13              01188
# 2                  Blé tendre        6.10              01136
# 3                  Blé tendre        1.32              01285
# 4                  Blé tendre        2.99              01398
# ...                       ...         ...                ...
# 1085952     Légumes ou fleurs        0.44              97404
# 1085953                Divers        1.56              97602
# 1085954     Légumes ou fleurs        0.35              97616
# 1085955              Fourrage        1.40              54234
# 1085956  Prairies permanentes        1.02              59157
#
#                     lbl_commune    code_epci code_departement  code_region  \
# 0                      Treffort  200030658.0               38           84
# 1                        Illiat  200070118.0               01           84
# 2        Cruzilles-lès-Mépillat  200070555.0               01           84
# 3                      Parcieux  200042497.0               01           84
# 4                     Savigneux  200042497.0               01           84
# ...                         ...          ...              ...          ...
# 1085952            L'Étang-Salé  249740077.0              974            4
# 1085953              Bandraboua  200060465.0              976            6
# 1085954                    Sada  200059871.0              976            6
# 1085955                   Gorcy  245400262.0               54           44
# 1085956                Cousolre  200043396.0               59           32
#
#             zone_geo                                           geometry
# 0        France mét.  MULTIPOLYGON (((5.67141 44.90419, 5.67144 44.9...
# 1        France mét.  MULTIPOLYGON (((4.87139 46.18659, 4.87152 46.1...
# 2        France mét.  MULTIPOLYGON (((4.87175 46.22321, 4.87171 46.2...
# 3        France mét.  MULTIPOLYGON (((4.84690 45.92268, 4.84606 45.9...
# 4        France mét.  MULTIPOLYGON (((4.85280 46.00945, 4.85280 46.0...
# ...              ...                                                ...
# 1085952         DROM  MULTIPOLYGON (((55.37057 -21.28207, 55.37057 -...
# 1085953         DROM  MULTIPOLYGON (((45.15010 -12.74134, 45.15022 -...
# 1085954         DROM  MULTIPOLYGON (((45.12145 -12.84818, 45.12104 -...
# 1085955  France mét.  MULTIPOLYGON (((5.67399 49.54902, 5.67428 49.5...
# 1085956  France mét.  MULTIPOLYGON (((4.15047 50.21344, 4.15058 50.2...
#
# [1085957 rows x 13 columns]

# %%
# on compare par groupe de culture ou par culture (les groupes ont moins évolué entre les millésimes)
var = 'grp'
surf_2019 = df_2019.groupby(f'{var.upper()}_CULTU')['SURFACE_HA'].sum().reset_index().rename(
    {f'{var.upper()}_CULTU': f'{var}_culture', 'SURFACE_HA': 'surface_ha'}, axis=1
)
surf_2022 = df_2022.groupby(f'{var}_culture')['surface_ha'].sum().reset_index()

# %%
merged = pd.merge(
    surf_2019,
    surf_2022,
    on=f'{var}_culture',
    how='outer',
    suffixes=['_2019', '_2022'],
)
merged['diff'] = merged['surface_ha_2022'] - merged['surface_ha_2019']
merged
# Out:
#                               grp_culture  surface_ha_2019  surface_ha_2022  \
# 0           Autres cultures industrielles         12020.65         21263.51
# 1                         Autres céréales        163069.46        207535.65
# 2                       Autres oléagineux         44625.02         63460.91
# 3                              Blé tendre        128786.59        171045.37
# 4                           Canne à sucre            82.04           425.88
# 5                                   Colza         11484.73         12505.47
# 6                                  Divers         24943.95         34836.82
# 7                       Estives et landes        226401.33        267500.53
# 8                                Fourrage        258617.20        343892.31
# 9                          Fruits à coque         12593.03         17413.94
# 10  Gel (surfaces gelées sans production)         15715.78         22603.28
# 11                      Légumes ou fleurs         30072.46         38819.71
# 12                  Légumineuses à grains         23318.81         21095.45
# 13                 Maïs grain et ensilage         85262.89         71791.07
# 14                               Oliviers          4307.19          5641.51
# 15                                   Orge         47963.35         49073.41
# 16                       Plantes à fibres          2944.48          6098.18
# 17                   Prairies permanentes        658089.61        780260.08
# 18                   Prairies temporaires        158943.11        202548.10
# 19                           Protéagineux         56619.28         66597.07
# 20                                    Riz          2920.59          2977.03
# 21                              Tournesol         35294.96         77195.64
# 22                                Vergers         26021.58         32684.71
# 23                                 Vignes         81231.70        136640.60
#
#          diff
# 0     9242.86
# 1    44466.19
# 2    18835.89
# 3    42258.78
# 4      343.84
# 5     1020.74
# 6     9892.87
# 7    41099.20
# 8    85275.11
# 9     4820.91
# 10    6887.50
# 11    8747.25
# 12   -2223.36
# 13  -13471.82
# 14    1334.32
# 15    1110.06
# 16    3153.70
# 17  122170.47
# 18   43604.99
# 19    9977.79
# 20      56.44
# 21   41900.68
# 22    6663.13
# 23   55408.90

# %%
fig = px.bar(
    merged.sort_values('diff', ascending=False),
    x=f'{var}_culture',
    y='diff',
    title=f'Evolution (en Ha) des "{var}_culture" entre 2019 et 2022',
)
fig.show(
#     renderer='png'
)
